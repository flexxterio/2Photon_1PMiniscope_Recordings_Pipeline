# %%
import caiman as cm
import os.path
from os import path
import os
import cv2
import numpy as np
from matplotlib import pyplot as plt
from IPython.display import clear_output
from tqdm import tqdm
from scipy.signal import butter, lfilter, freqz, filtfilt
import json
import glob
import shutil
from pathlib import Path

# %%
#optimal pollen density
single_movie = cm.load('D:/2022_06_20/14_05_03/Miniscope/0.avi')
print(single_movie.shape)

import matplotlib.pyplot as plt
plt.imshow(np.mean(single_movie,0))
plt.imshow(np.std(single_movie,0))
plt.plot(np.mean(single_movie, axis = (1,2)))
# Out:
# (1000, 608, 608)

# %%
#optimal pollen density
single_movie1 = cm.load('D:/2022_06_20/14_46_07/Miniscope/0.avi')
print(single_movie1.shape)


import matplotlib.pyplot as plt
plt.imshow(np.mean(single_movie1,0))
plt.imshow(np.std(single_movie1,0))
plt.plot(np.mean(single_movie1, axis = (1,2)))
# Out:
# (1000, 608, 608)

# %%
#optimal pollen density
single_movie2 = cm.load('D:/2022_06_20/14_54_38/Miniscope/0.avi')
print(single_movie2.shape)


import matplotlib.pyplot as plt
plt.imshow(np.mean(single_movie2,0))
plt.imshow(np.std(single_movie2,0))
plt.plot(np.mean(single_movie2, axis = (1,2)))
# Out:
# (1000, 608, 608)

# %%
#optimal pollen density
single_movie3 = cm.load('D:/2022_06_20/14_56_51/Miniscope/0.avi')
print(single_movie3.shape)


import matplotlib.pyplot as plt
plt.imshow(np.mean(single_movie3,0))
plt.imshow(np.std(single_movie3,0))
plt.plot(np.mean(single_movie3, axis = (1,2)))
# Out:
# (1000, 608, 608)

# %%
#optimal pollen density
single_movie4 = cm.load('D:/2022_06_20/14_58_35/Miniscope/0.avi')
print(single_movie4.shape)


import matplotlib.pyplot as plt
plt.imshow(np.mean(single_movie4,0))
plt.imshow(np.std(single_movie4,0))
plt.plot(np.mean(single_movie4, axis = (1,2)))
# Out:
# (1000, 608, 608)

# %%
#optimal pollen density
single_movie4 = cm.load('D:/2022_06_20/14_58_35/Miniscope/0.avi')
print(single_movie4.shape)


import matplotlib.pyplot as plt
plt.imshow(np.mean(single_movie4,0))
plt.imshow(np.std(single_movie4,0))
plt.plot(np.mean(single_movie4, axis = (1,2)))

# %%
single_movie4.play(magnification = 1, fr=30, q_min=0.1, q_max=99.75)

# %%
#chosen file for the old brain: 16_44_21

single_movie = cm.load('C:/Users/Katherin/Documents/caiman/cleaning_function/0.avi')
print(single_movie.shape)

import matplotlib.pyplot as plt
plt.imshow(np.mean(single_movie,0))
plt.imshow(np.std(single_movie,0))
plt.plot(np.mean(single_movie, axis = (1,2)))
# Out:
# (1000, 608, 608)

# %%
miniscope_im = np.mean(single_movie, 0)
miniscope_im2 = miniscope_im[48:560,48:560]
miniscope_im2.shape
# %store miniscope_im2
# Out:
# Stored 'miniscope_im2' (movie)

# %%
plt.imshow(miniscope_im)

# %%
single_movie1 = cm.load('C:/Users/Katherin/Documents/caiman/1.avi')

# %%
single_movie1.play(magnification = 1, fr=30, q_min=0.1, q_max=99.75)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [16], in <cell line: 1>()
# ----> 1 single_movie1.play(magnification = 1, fr=30, q_min=0.1, q_max=99.75)
#
# File ~\miniconda3\envs\caiman\lib\site-packages\caiman\base\movies.py:1350, in movie.play(self, gain, fr, magnification, offset, interpolation, backend, do_loop, bord_px, q_max, q_min, plot_text, save_movie, opencv_codec, movie_name)
#    1348     frame = np.minimum((frame * 255.), 255).astype('u1')
#    1349     out.write(frame)
# -> 1350 if cv2.waitKey(int(1. / fr * 1000)) & 0xFF == ord('q'):
#    1351     looping = False
#    1352     terminated = True
#
# KeyboardInterrupt:

# %%
print(single_movie.shape)
plt.plot(np.min(np.min(single_movie[:,300:500, 300:500],1),1))
print(np.min(single_movie[:,300:400, 300:400],1).shape)
# Out:
# (1000, 608, 608)
# (1000, 100)

# %%
# here we are plotting all the minimums for each slide (1000 in total), for this we are collapsing each frame 608*608 to 608
# values along chosen axis (normally 1), and then we are collapsing them again to get one minimum from each slide,
# so for 1000 slides we are getting one value and then we can plot them all to see where the values are different
# (basically close to zero, bc zero is black). Also we need to cut the corners, because they are black and itsmaking all
# frames to have minimum close or even almost equal to zero
min1 = np.min(single_movie[:,200:400,200:400],1)
min1.shape
min2 = np.min(min1,1)
plt.plot(min2)

# %%
# how to play slices
# single_movie[400:900,:,:].play(magnification = 2, fr=30, q_min=0.1, q_max=99.75)

# %%
single_movie.play(magnification = 2, fr=30, q_min=0.1, q_max=99.75)

# %%
import matplotlib.pyplot as plt
plt.imshow(np.mean(single_movie,0))
plt.imshow(np.std(single_movie,0))
plt.plot(np.mean(single_movie, axis = (1,2)))

# %%
single_movie.play(magnification = 2, fr=30, q_min=0.1, q_max=99.75)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [36], in <cell line: 1>()
# ----> 1 single_movie.play(magnification = 2, fr=30, q_min=0.1, q_max=99.75)
#
# File ~\miniconda3\envs\caiman\lib\site-packages\caiman\base\movies.py:1350, in movie.play(self, gain, fr, magnification, offset, interpolation, backend, do_loop, bord_px, q_max, q_min, plot_text, save_movie, opencv_codec, movie_name)
#    1348     frame = np.minimum((frame * 255.), 255).astype('u1')
#    1349     out.write(frame)
# -> 1350 if cv2.waitKey(int(1. / fr * 1000)) & 0xFF == ord('q'):
#    1351     looping = False
#    1352     terminated = True
#
# KeyboardInterrupt:

# %%
single_movie = cm.load('0.avi')
print(single_movie.shape)
# Out:
# (668, 608, 608)

# %%
single_movie.play(magnification = 2, fr=30, q_min=0.1, q_max=99.75)

# %%
minisc_im = np.mean(single_movie,0)
minisc_im.shape
plt.imshow(minisc_im)
np.save('minisc_im.npy',minisc_cut_im)
minisc_im_nocut = np.load('minisc_im.npy')
# %store minisc_im_nocut
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [6], in <cell line: 4>()
#       2 minisc_im.shape
#       3 plt.imshow(minisc_im)
# ----> 4 np.save('minisc_im.npy',minisc_cut_im)
#       5 minisc_im_nocut = np.load('minisc_im.npy')
#       6 get_ipython().run_line_magic('store', 'minisc_im_nocut')
#
# NameError: name 'minisc_cut_im' is not defined

# %%
minisc_im = np.mean(single_movie,0)
minisc_cut_im = minisc_im[48:560,48:560]
minisc_cut_im.shape
plt.imshow(minisc_cut_im, "gray")

# %%
from PIL import Image
im = Image.open("test_miniscope.png")
im.size  # (364, 471)
# Out:
# (432, 288)

# %%
test_miniscope.png

# %%
mkdir image_data

# %%
import matplotlib.pyplot as plt
plt.imshow(np.mean(single_movie,0))
plt.imshow(np.std(single_movie,0))
plt.plot(np.mean(single_movie, axis = (1,2)))

# %%
np.save('minisc_cut_im',minisc_cut_im)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [5], in <cell line: 1>()
# ----> 1 np.save('minisc_cut_im',minisc_cut_im)
#
# NameError: name 'minisc_cut_im' is not defined

# %%
# here I want to try to convert this video into 1 image, Im going to take 1 movie wyth 
# one frame and get this one frame as an image
import cv2
import os

def video_to_frames(video, path_output_dir):
    # extract frames from a video and save to directory as 'x.png' where 
    # x is the frame index
    vidcap = cv2.VideoCapture(video)
    count = 0
    while vidcap.isOpened():
        success, image = vidcap.read()
        if success:
            cv2.imwrite(os.path.join(path_output_dir, '%d.png') % count, image)
            count += 1
        else:
            break
    cv2.destroyAllWindows()
    vidcap.release()

# %%
video_to_frames('minisc_cut_im', 'C:/Users/Katherin/Documents/caiman/frames')

# %%
minisc_cut_im2 = np.load('minisc_cut_im.npy')

# %%
plt.imshow(minisc_cut_im2)
# %store minisc_cut_im2
# Out:
# Stored 'minisc_cut_im2' (ndarray)

# %%
import matplotlib.pyplot as plt
plt.imshow(np.mean(single_movie,0)-np.min(single_movie,0))
#plt.imshow(np.std(single_movie,0))
#plt.plot(np.mean(single_movie, axis = (1,2)))

# %%
CI = single_movie.local_correlations(eight_neighbours=True, swap_dim=False)
plt.imshow(CI)
# %store CI
CI.shape
# Out:
# Stored 'CI' (ndarray)
# (608, 608)

# %%
Yoo = np.mean(single_movie, axis = (1,2))

# %%
CI.shape
# Out:
# (608, 608)

# %%
CI_inverted = np.invert(CI)
plt.imshow(CI_inverted)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [22], in <cell line: 1>()
# ----> 1 CI_inverted = np.invert(CI)
#       2 plt.imshow(CI_inverted)
#
# TypeError: ufunc 'invert' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''

# %%
def clean_miniscope(dataDir):
    def getint(name):   ##splits the file names according to the int of the video
        #int(os.path.split(fnames[0])[1].partition('.')[0])
        num = int(os.path.split(name)[1].partition('.')[0])
        return int(num)


    curpath = os.getcwd()
    # Need pip install ipympl

    # %matplotlib widget
    plt.rcParams["figure.figsize"] = (10, 5)

    if not os.path.exists(dataDir / 'cleaned/'):
        os.mkdir(dataDir / 'cleaned/')
    startingFileNum = 0
    framesPerFile = 1000 # This is the default setting for the Miniscope software. If you changed it in software change it here too.

    fnames = list(dataDir.glob('*.avi'))
    fnames.sort(key=os.path.getctime)
    fnames.sort(key=getint)
    cutOfffrequency = 3
    with open(dataDir / 'metaData.json') as f:
        metadata = json.load(f)

    fr = metadata['frameRate']
    try:
        if fr[-3:] == 'FPS':  # depending on which metadata file it reads, it will either get the value or the value plus FPS attached. This cleans the value from 'FPS'
            fr = fr[:-3]
            fr = int(fr)
    except:
        print(fr)
    # Makes sure path ends with '/'
    #if (dataDir[-1] != "/"):
    #    dataDir = dataDir + "/"





        # Run through avi files and generate mean fft

    # Values users can modify:
    frameStep = 3 # Can use frame skipping to speed this up
    showVideo = False
    # -----------------------

    fileNum = startingFileNum
    sumFFT = None
    applyVignette = True
    vignetteCreated = False
    running = True

    #while (path.exists(dataDir + "{:.0f}.avi".format(fileNum)) and running is True):   #if the files are not called cropped_*.avi
    while (fileNum < len(fnames) and running is True):
        videofname = fnames[fileNum]
        cap = cv2.VideoCapture(videofname.as_posix())
        fileNum = fileNum + 1
        frameNum = 0
        for frameNum in tqdm(range(0,framesPerFile, frameStep), total = framesPerFile/frameStep, desc ="Running file {:.0f}.avi".format(fileNum - 1)):
            cap.set(cv2.CAP_PROP_POS_FRAMES, frameNum)
            ret, frame = cap.read()

            if (vignetteCreated is False):
                rows, cols = frame.shape[:2]
                X_resultant_kernel = cv2.getGaussianKernel(cols,cols/4)
                Y_resultant_kernel = cv2.getGaussianKernel(rows,rows/4)
                resultant_kernel = Y_resultant_kernel * X_resultant_kernel.T
                mask = 255 * resultant_kernel / np.linalg.norm(resultant_kernel)
                vignetteCreated = True

            if applyVignette is False:
                mask = mask * 0 + 1

            if (ret is False):
                break
            else:
                frame = frame[:,:,1] * mask

                dft = cv2.dft(np.float32(frame),flags = cv2.DFT_COMPLEX_OUTPUT)
                dft_shift = np.fft.fftshift(dft)

                if fileNum == 1 and frameNum == 0:
                    sumFFT = cv2.magnitude(dft_shift[:, :, 0], dft_shift[:, :, 1])  # without this if else it will lead to sigsev sometimes
                else:
                    sumFFT = sumFFT + cv2.magnitude(dft_shift[:, :, 0], dft_shift[:, :, 1])
                #try:
                #    sumFFT = sumFFT + cv2.magnitude(dft_shift[:,:,0],dft_shift[:,:,1])
                #except:
                #    sumFFT = cv2.magnitude(dft_shift[:, :, 0], dft_shift[:, :, 1])  # this line crashes with sigsev

                if (showVideo is True):
                    cv2.imshow("Vid", frame/255)
                    if cv2.waitKey(10) & 0xFF == ord('q'):
                        running = False
                        break

    cv2.destroyAllWindows()




    # Modify FFT using a circle mask around center

    # Values users can modify:
    goodRadius = 2000
    notchHalfWidth = 3
    centerHalfHeightToLeave = 20
    # -----------------------

    crow,ccol = int(rows/2) , int(cols/2)

    maskFFT = np.zeros((rows,cols,2), np.float32)
    cv2.circle(maskFFT,(crow,ccol),goodRadius,1,thickness=-1)

    # for i in cutFreq:
    #     maskFFT[(i + crow-notchHalfWidth):(i+crow+notchHalfWidth),(ccol-notchHalfWidth):(ccol+notchHalfWidth),0] = 0
    #     maskFFT[(-i + crow-notchHalfWidth):(-i+crow+notchHalfWidth),(ccol-notchHalfWidth):(ccol+notchHalfWidth),0] = 0
    maskFFT[(crow+centerHalfHeightToLeave):,(ccol-notchHalfWidth):(ccol+notchHalfWidth),0] = 0
    maskFFT[:(crow-centerHalfHeightToLeave),(ccol-notchHalfWidth):(ccol+notchHalfWidth),0] = 0

    maskFFT[:,:,1] = maskFFT[:,:,0]


    modifiedFFT = sumFFT * maskFFT[:,:,0]

    # Plot original and modified FFT
    plt.figure()
    plt.subplot(121),plt.imshow(np.log(sumFFT), cmap = 'gray')
    plt.title('Mean FFT of Data')
    plt.subplot(122),plt.imshow(np.log(modifiedFFT), cmap = 'gray')
    plt.title('Filtered FFT')




    # Display filtered vs original videos

    # Values users can modify:
    frameStep = 20 # This will speed up the playback
    # -----------------------

    fileNum = startingFileNum
    sumFFT = None
    running = True

    # while (path.exists(fnames[fileNum]) and running is True):
    while (fileNum < len(fnames) and running is True):
        videofname = fnames[fileNum]
        cap = cv2.VideoCapture(videofname.as_posix())
        fileNum = fileNum + 1
        for frameNum in tqdm(range(0,framesPerFile, frameStep), total = framesPerFile/frameStep, desc ="Running file {}".format(videofname)):
            cap.set(cv2.CAP_PROP_POS_FRAMES, frameNum)
            ret, frame = cap.read()

            if (ret is False):
                break
            else:
                frame = frame[:,:,1]
                dft = cv2.dft(np.float32(frame),flags = cv2.DFT_COMPLEX_OUTPUT|cv2.DFT_SCALE)
                dft_shift = np.fft.fftshift(dft)

                fshift = dft_shift * maskFFT
                f_ishift = np.fft.ifftshift(fshift)
                img_back = cv2.idft(f_ishift)
                img_back = cv2.magnitude(img_back[:,:,0],img_back[:,:,1])

                img_back[img_back >255] = 255
                img_back = np.uint8(img_back)

                im_diff = (128 + (frame - img_back)*2)
                im_v = cv2.hconcat([frame, img_back, im_diff])
                cv2.imshow("Raw, Filtered, Difference", im_v/255)

                if fileNum == 1 and frameNum == 0:
                    sumFFT = cv2.magnitude(dft_shift[:, :, 0], dft_shift[:, :, 1])  # without this if else it will lead to sigsev sometimes
                else:
                    sumFFT = sumFFT + cv2.magnitude(dft_shift[:, :, 0], dft_shift[:, :, 1])

                #try:
                #    sumFFT = sumFFT + cv2.magnitude(dft_shift[:,:,0],dft_shift[:,:,1])
                #except:
                #    sumFFT = cv2.magnitude(dft_shift[:,:,0],dft_shift[:,:,1])

                if cv2.waitKey(10) & 0xFF == ord('q'):
                    running = False
                    break

    cv2.destroyAllWindows()









    # Calculate mean fluorescence per frame

    # Users shouldn't change anything here
    frameStep = 1 # Should stay as 1
    fileNum = startingFileNum
    sumFFT = None
    meanFrameList = []


    while (fileNum < len(fnames) and running is True):
        videofname = fnames[fileNum]
        cap = cv2.VideoCapture(videofname.as_posix())
        fileNum = fileNum + 1
        for frameNum in tqdm(range(0,framesPerFile, frameStep), total = framesPerFile/frameStep, desc ="Running file {}".format(videofname)):
            cap.set(cv2.CAP_PROP_POS_FRAMES, frameNum)
            ret, frame = cap.read()

            if (ret is False):
                break
            else:
                frame = frame[:,:,1]
                dft = cv2.dft(np.float32(frame),flags = cv2.DFT_COMPLEX_OUTPUT|cv2.DFT_SCALE)
                dft_shift = np.fft.fftshift(dft)

                fshift = dft_shift * maskFFT
                f_ishift = np.fft.ifftshift(fshift)
                img_back = cv2.idft(f_ishift)
                img_back = cv2.magnitude(img_back[:,:,0],img_back[:,:,1])
                meanFrameList.append(img_back.mean())

                # clear_output(wait=True)

                # plt.subplot(121),plt.imshow(frame, cmap = 'gray')
                # plt.title('Input Image'), plt.xticks([]), plt.yticks([])
                # plt.subplot(122),plt.imshow(img_back, cmap = 'gray')
                # plt.title('Magnitude Spectrum'), plt.xticks([]), plt.yticks([])

                # plt.show()
    meanFrame = np.array(meanFrameList)






    # Create a lowpass filter
    # Sample rate and desired cutoff frequencies (in Hz).

    # Values users can modify:
    fs = fr
    cutoff   = cutOfffrequency
    # fs = 10 # TODO: Should get this from timestamp file
    # cutoff = 3.0
    # -----------------------

    plt.figure()
    for order in [3, 6, 9]:
        b, a = butter(order, cutoff/ (0.5 * fs), btype='low', analog = False)
        w, h = freqz(b, a, worN=2000)
        plt.plot((fs * 0.5 / np.pi) * w, abs(h), label="order = %d" % order)

    plt.plot([0, 0.5 * fs], [np.sqrt(0.5), np.sqrt(0.5)],
                 '--', label='sqrt(0.5)')
    plt.xlabel('Frequency (Hz)')
    plt.ylabel('Gain')
    plt.grid(True)
    plt.legend(loc='best')
    # Plot Mean Frame Resuls
    # plt.figure(figsize=(8,4))
    # plt.plot(meanFrame)







    # Plot effect of filtering

    # Values users can modify:
    butterOrder = 6
    # -----------------------

    b, a = butter(butterOrder, cutoff/ (0.5 * fs), btype='low', analog = False)
    meanFiltered = filtfilt(b,a,meanFrame)
    plt.figure()
    plt.plot(meanFrame, 'k', label='Raw Data')
    plt.plot( meanFiltered, label='Filtered Data')
    plt.plot(meanFrame - meanFiltered,'r', label='Difference')
    plt.xlabel('frame number')
    # plt.hlines([-a, a], 0, T, linestyles='--')
    plt.grid(True)
    plt.axis('tight')
    plt.legend(loc='upper left')
    # meanFrame[3000]







    # Apply FFT spatial filtering and lowpass filtering to data and save as new videos

    # Values users can modify:
    # Select one below -
    # mode = "display"
    mode = "save"

    frameStep = 1 #10 # Should be set to 1 for saving

    # Select one below -
    # compressionCodec = "FFV1"
    compressionCodec = "GREY"
    # --------------------

    fileNum = startingFileNum
    sumFFT = None
    frameCount = 0
    running = True

    if (mode is "save" and frameStep is not 1):
        print("WARNING: You are only saving every {} frame!".format(frameStep))

    codec = cv2.VideoWriter_fourcc(compressionCodec[0],compressionCodec[1],compressionCodec[2],compressionCodec[3])

    while (fileNum < len(fnames) and running is True):
        videofname = fnames[fileNum]
        cap = cv2.VideoCapture(videofname.as_posix())

        if (mode is "save"):
            writeFile = cv2.VideoWriter((dataDir / "cleaned{:.0f}.avi".format(fileNum)).as_posix(),
                                codec, fr, (rows,cols), isColor=False)

        fileNum = fileNum + 1
        # frameNum = 0
        for frameNum in tqdm(range(0,framesPerFile, frameStep), total = framesPerFile/frameStep, desc ="Running file {:.0f}.avi".format(fileNum - 1)):
            cap.set(cv2.CAP_PROP_POS_FRAMES, frameNum)
            ret, frame = cap.read()
            # frameNum = frameNum + frameStep

            # print(frameCount)

            if (ret is False):
                break
            else:
                frame = frame[:,:,1]
                dft = cv2.dft(np.float32(frame),flags = cv2.DFT_COMPLEX_OUTPUT|cv2.DFT_SCALE)
                dft_shift = np.fft.fftshift(dft)

                fshift = dft_shift * maskFFT
                f_ishift = np.fft.ifftshift(fshift)
                img_back = cv2.idft(f_ishift)
                img_back = cv2.magnitude(img_back[:,:,0],img_back[:,:,1])

                meanF = img_back.mean()
                img_back = img_back * (1 + (meanFiltered[frameCount] - meanF)/meanF)
                img_back[img_back >255] = 255
                img_back = np.uint8(img_back)



                if (mode is "save"):
                    writeFile.write(img_back)

                if (mode is "display"):
                    im_diff = (128 + (frame - img_back)*2)
                    im_v = cv2.hconcat([frame, img_back])
                    im_v = cv2.hconcat([im_v, im_diff])

                    im_v = cv2.hconcat([frame, img_back, im_diff])
                    cv2.imshow("Cleaned video", im_v/255)
                    if cv2.waitKey(1) & 0xFF == ord('q'):
                        running = False
                        cap.release()
                        break

                frameCount = frameCount + 1

        if (mode is "save"):
            writeFile.release()

    cv2.destroyAllWindows()
    for ii in list(dataDir.glob('cleaned*.avi')):
        tmpname = ii.name
        shutil.move(ii, dataDir / 'cleaned' / tmpname)
        print(ii)
    shutil.copyfile(dataDir / 'metaData.json', dataDir / 'cleaned' / 'metaData.json')
    print('done with {}'.format(dataDir))
    plt.close('all')
    return dataDir / 'cleaned/'
# Out:
# <>:320: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:320: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# <>:329: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:361: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:364: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:378: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:320: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:320: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# <>:329: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:361: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:364: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:378: SyntaxWarning: "is" with a literal. Did you mean "=="?
# C:\Users\Katherin\AppData\Local\Temp\ipykernel_18516\599466385.py:320: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if (mode is "save" and frameStep is not 1):
# ...

# %%
clean_miniscope(Path('C:/Users/Katherin/Documents/caiman/cleaning_function'))
# Out:
# Running file 0.avi: 334it [01:51,  2.99it/s]
# C:\Users\Katherin\AppData\Local\Temp\ipykernel_18516\599466385.py:131: RuntimeWarning: divide by zero encountered in log
#   plt.subplot(122),plt.imshow(np.log(modifiedFFT), cmap = 'gray')
# Running file C:\Users\Katherin\Documents\caiman\cleaning_function\0.avi: 100%|███████| 50/50.0 [00:16<00:00,  3.12it/s]
# Running file C:\Users\Katherin\Documents\caiman\cleaning_function\0.avi: 100%|███| 1000/1000.0 [05:25<00:00,  3.07it/s]
# Running file 0.avi: 100%|████████████████████████████████████████████████████████| 1000/1000.0 [05:00<00:00,  3.33it/s]
# C:\Users\Katherin\Documents\caiman\cleaning_function\cleaned0.avi
# done with C:\Users\Katherin\Documents\caiman\cleaning_function
# WindowsPath('C:/Users/Katherin/Documents/caiman/cleaning_function/cleaned')

# %%
from pathlib import Path

# %%
Path('C:/Users/Katherin/Documents/caiman')

# %%
single_movie1 = cm.load('cleaned0-Copy1.avi')

# %%
single_movie1.play(magnification = 2, fr=30, q_min=0.1, q_max=99.75)

# %%
plt.imshow(np.mean(single_movie1,0))
plt.imshow(np.std(single_movie1,0))
plt.plot(np.mean(single_movie1, axis = (1,2)))
plt.rcParams["figure.figsize"]= (10,6)
plt.savefig('test_pic.png')

# %%
# read image
img = cv2.imread("test_pic_cutbyhand.png")

# convert img to grayscale
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# do adaptive threshold on gray image
thresh = cv2.adaptiveThreshold(gray, 700, cv2.ADAPTIVE_THRESH_MEAN_C, cv2.THRESH_BINARY, 25, 6)

# write results to disk
cv2.imwrite("dots_thresh.jpg", thresh)

# display it
cv2.imshow("thresh", thresh)
cv2.waitKey(0)

# %%
img = cv2.imread('test_pic_cutbyhand.png',0)

ret,thresh1 = cv2.threshold(img,127,255,cv2.THRESH_BINARY)
thresh2 = cv2.adaptiveThreshold(img,255,cv2.ADAPTIVE_THRESH_MEAN_C,
                                    cv2.THRESH_BINARY,11,2)
thresh3 = cv2.adaptiveThreshold(img,255,cv2.ADAPTIVE_THRESH_GAUSSIAN_C,
                                    cv2.THRESH_BINARY,11,2)

plt.subplot(221), plt.imshow(img,'gray')
plt.title('Original Image')
plt.subplot(222), plt.imshow(thresh1, 'gray')
plt.title('THRESH_BINARY')
plt.subplot(223), plt.imshow(thresh2, 'gray')
plt.title('ADAPTIVE_THRESH_MEAN_C')
plt.subplot(224), plt.imshow(thresh3, 'gray')
plt.title('ADAPTIVE_THRESH_GAUSSIAN_C')

plt.show()

# %%
img = cv2.imread('test_pic_cutbyhand.png',0)
# global thresholding
ret1,th1 = cv2.threshold(img,127,255,cv2.THRESH_BINARY)
# Otsu's thresholding
ret2,th2 = cv2.threshold(img,0,255,cv2.THRESH_BINARY+cv2.THRESH_OTSU)
# Otsu's thresholding after Gaussian filtering
blur = cv2.GaussianBlur(img,(5,5),0)
ret3,th3 = cv2.threshold(blur,0,255,cv2.THRESH_BINARY+cv2.THRESH_OTSU)

# %%
img = cv2.imread('test_pic_cutbyhand.png')
gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
ret, thresh = cv2.threshold(gray,0,255,cv2.THRESH_BINARY_INV+cv2.THRESH_OTSU)
# noise removal
kernel = np.ones((3,3),np.uint8)
opening = cv2.morphologyEx(thresh,cv2.MORPH_OPEN,kernel, iterations = 2)
# sure background area
sure_bg = cv2.dilate(opening,kernel,iterations=3)
# Finding sure foreground area
dist_transform = cv2.distanceTransform(opening,cv2.DIST_L2,5)
ret, sure_fg = cv2.threshold(dist_transform,0.7*dist_transform.max(),255,0)
# Finding unknown region
sure_fg = np.uint8(sure_fg)
unknown = cv2.subtract(sure_bg,sure_fg)
# Marker labelling
ret, markers = cv2.connectedComponents(sure_fg)
# Add one to all labels so that sure background is not 0, but 1
markers = markers+1
# Now, mark the region of unknown with zero
markers[unknown==255] = 0

# %%
markers = cv2.watershed(img,markers)
img[markers == -1] = [255,0,0]

# %%
plt.imshow(markers)

# %%
plt.imshow(th3, 'gray')

# %%
plt.imshow(thresh2, 'gray')

# %%
plt.imshow(thresh3, 'gray')

# %%
img = cv2.imread('test_pic_cutbyhand.png')

rows, cols = img.shape[:2]
frame = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)

img_out = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
ret,img_out = cv2.threshold(img_out,127,255,cv2.THRESH_OTSU)
img_out = frame
cv2.imshow('original',img)
cv2.imshow('output',img_out)
cv2.waitKey()

# %%
img = cv2.imread('test_pic_cutbyhand.png')
gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)

#thresh2 = cv2.adaptiveThreshold(img,255,cv2.ADAPTIVE_THRESH_MEAN_C,
                                    #cv2.THRESH_BINARY,11,2)
ret,img_out = cv2.adaptiveThreshold(gray,255,127,cv2.THRESH_OTSU)
plt.imshow(img_out, 'gray')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [17], in <cell line: 6>()
#       2 gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
#       4 #thresh2 = cv2.adaptiveThreshold(img,255,cv2.ADAPTIVE_THRESH_MEAN_C,
#       5                                     #cv2.THRESH_BINARY,11,2)
# ----> 6 ret,img_out = cv2.adaptiveThreshold(gray,255,127,cv2.THRESH_OTSU)
#       7 plt.imshow(img_out, 'gray')
#
# TypeError: adaptiveThreshold() missing required argument 'blockSize' (pos 5)

# %%
img = cv2.imread('test_pic_cutbyhand.png')
gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
twoDimage = gray.reshape((-1,3))
twoDimage = np.float32(twoDimage)
criteria = (cv2.TERM_CRITERIA_EPS + cv2.TERM_CRITERIA_MAX_ITER, 10, 1.0)
K = 6
attempts=10
ret,label,center=cv2.kmeans(twoDimage,K,None,criteria,attempts,cv2.KMEANS_PP_CENTERS)
center = np.uint8(center)
res = center[label.flatten()]
result_image = res.reshape((gray.shape))
plt.imshow(result_image, 'gray')

# %%
img = cv2.imread('test_pic_cutbyhand.png')
gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
#blur = cv2.GaussianBlur(img,(5,5),0)
ret,thresh = cv2.threshold(gray,0,255,cv2.THRESH_BINARY+cv2.THRESH_OTSU)
#gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
#ret, thresh = cv2.threshold(gray,0,255,cv2.THRESH_BINARY_INV+cv2.THRESH_OTSU)
# noise removal
kernel = np.ones((3,3),np.uint8)
opening = cv2.morphologyEx(thresh,cv2.MORPH_OPEN,kernel, iterations = 2)
# sure background area
sure_bg = cv2.dilate(opening,kernel,iterations=3)
# Finding sure foreground area
dist_transform = cv2.distanceTransform(opening,cv2.DIST_L2,5)
ret, sure_fg = cv2.threshold(dist_transform,0.7*dist_transform.max(),255,0)
# Finding unknown region
sure_fg = np.uint8(sure_fg)
unknown = cv2.subtract(sure_bg,sure_fg)
# Marker labelling
ret, markers = cv2.connectedComponents(sure_fg)
# Add one to all labels so that sure background is not 0, but 1
markers = markers+1
# Now, mark the region of unknown with zero
markers[unknown==255] = 0
markers = cv2.watershed(img,markers)
img[markers == -1] = [255,0,0]
plt.imshow(img, 'gray')

# %%
plt.imshow(markers, 'gray')

# %%
markers = cv2.watershed(img,markers)
img[markers == -1] = [255,0,0]

# %%
img = cv2.imread('test_pic_cutbyhand.png')
img_rgb=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
img_gray=cv2.cvtColor(img_rgb,cv2.COLOR_RGB2GRAY)

def filter_image(image, mask):
    r = image[:,:,0] * mask
    g = image[:,:,1] * mask
    b = image[:,:,2] * mask
    return np.dstack([r,g,b])

thresh = cv2.THRESH_OTSU(img_gray)
img_otsu  = img_gray < thresh
filtered = filter_image(img, img_otsu)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [27], in <cell line: 11>()
#       8     b = image[:,:,2] * mask
#       9     return np.dstack([r,g,b])
# ---> 11 thresh = cv2.THRESH_OTSU(img_gray)
#      12 img_otsu  = img_gray < thresh
#      13 filtered = filter_image(img, img_otsu)
#
# TypeError: 'int' object is not callable

# %%
mse_list = []
arr = np.zeros((25,25), dtype="float32")


for j in range (0,25):
    for i in range (0,25):
            arr[j,i] = mse(imstack2[i,115:350,115:350], imstack2[j, 115:350,115:350])
            #mse_list.append(s)
    #np.append(arr[j,:],mse_list)
